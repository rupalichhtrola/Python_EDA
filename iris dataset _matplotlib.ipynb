# %%
import seaborn as sns
import pandas as pd
import numpy as np

# %%
df=sns.load_dataset('tips')

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df=sns.load_dataset('titanic')

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
import matplotlib.pyplot as plt 
import pandas as pd
import numpy as np
# %matplotlib inline

# %%
arr=np.random.rand(1000)
arr
# Out:
# array([0.2361425 , 0.60212322, 0.7270458 , 0.53020004, 0.28864635,
#        0.84651391, 0.36985827, 0.74955412, 0.57456582, 0.96118382,
#        0.23669935, 0.76410911, 0.16208019, 0.21426486, 0.16773604,
#        0.23974352, 0.50328421, 0.69185967, 0.0777354 , 0.01612708,
#        0.89088956, 0.50090162, 0.57815434, 0.32175794, 0.92741031,
#        0.65056169, 0.82167378, 0.57090788, 0.51543649, 0.44444906,
#        0.90144957, 0.47984135, 0.56957615, 0.6098988 , 0.14055543,
#        0.22600736, 0.06402548, 0.45958984, 0.54241884, 0.05764314,
#        0.08659161, 0.99607974, 0.18573327, 0.98971515, 0.770779  ,
#        0.19961692, 0.72387236, 0.05681009, 0.40249118, 0.06089233,
#        0.60575514, 0.99072295, 0.01905483, 0.6187156 , 0.89999752,
#        0.72333909, 0.05739626, 0.05074032, 0.06290762, 0.93877244,
#        0.03171617, 0.0755206 , 0.01407444, 0.90655395, 0.97931524,
#        0.06161217, 0.70019734, 0.2600102 , 0.01353796, 0.83097847,
# ...

# %%
type(arr)
# Out:
# numpy.ndarray

# %%
df=pd.DataFrame(arr,columns=['DATA'])
df.head(5)
# Out:
#        DATA
# 0  0.236143
# 1  0.602123
# 2  0.727046
# 3  0.530200
# 4  0.288646

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
df.plot(figsize=(20,10))
# Out:
# <AxesSubplot:>

# %%
import seaborn as sns

# %%
df=sns.load_dataset("iris")

# %%
df.head(10)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
# 5           5.4          3.9           1.7          0.4  setosa
# 6           4.6          3.4           1.4          0.3  setosa
# 7           5.0          3.4           1.5          0.2  setosa
# 8           4.4          2.9           1.4          0.2  setosa
# 9           4.9          3.1           1.5          0.1  setosa

# %%
df.plot(figsize=(20,10))
# Out:
# <AxesSubplot:>

# %%
df.plot(kind='bar',figsize=(20,10))
# Out:
# <AxesSubplot:>

# %%
df.iloc[5:11]
# Out:
#     sepal_length  sepal_width  petal_length  petal_width species
# 5            5.4          3.9           1.7          0.4  setosa
# 6            4.6          3.4           1.4          0.3  setosa
# 7            5.0          3.4           1.5          0.2  setosa
# 8            4.4          2.9           1.4          0.2  setosa
# 9            4.9          3.1           1.5          0.1  setosa
# 10           5.4          3.7           1.5          0.2  setosa

# %%
df.iloc[5:11].plot(kind='bar',figsize=(20,10))
# Out:
# <AxesSubplot:>

# %%
df.iloc[5:11].plot(kind='barh',figsize=(20,10))
# Out:
# <AxesSubplot:>

# %%
df.plot(kind='hist',figsize=(20,10))
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df.iloc[5:11].plot(kind='hist',figsize=(20,10))
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df['sepal_length'].plot(kind='hist',figsize=(20,10),orientation='horizontal')
# Out:
# <AxesSubplot:xlabel='Frequency'>

# %%
df.plot(kind='box',figsize=(20,10))
# Out:
# <AxesSubplot:>

# %%
df.hist(figsize=(20,10),color="r",alpha=0.8)
# Out:
# array([[<AxesSubplot:title={'center':'sepal_length'}>,
#         <AxesSubplot:title={'center':'sepal_width'}>],
#        [<AxesSubplot:title={'center':'petal_length'}>,
#         <AxesSubplot:title={'center':'petal_width'}>]], dtype=object)

# %%
df.plot(kind='box',figsize=(20,10),color={'boxes':'r','whiskers':'b'})
# Out:
# <AxesSubplot:>

# %%
df.plot(kind='area',figsize=(20,10),alpha=0.4,stacked=True)
# Out:
# <AxesSubplot:>

# %%
df.plot.scatter(x='sepal_length',y='petal_length',c='sepal_width',s=100)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
df.plot.scatter(x='sepal_length',y='petal_length',c='sepal_width',s=df['sepal_length']*100)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
df.plot.hexbin(x='sepal_length',y='petal_length',gridsize=5)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
df.head(5)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df1=df.drop(columns='species').iloc[0]
df1.plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='0'>
